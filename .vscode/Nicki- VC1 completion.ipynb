# %%
import os
import numpy as np
import pandas as pd
import rapidminer

rm = rapidminer.Studio("C:\Program Files\RapidMiner\RapidMiner Studio")

# %%
df = rapidminer.Project().read(r'C:\Users\ajain46\OneDrive\JAGUAR LAND ROVER\Network Excellence Reporting & Analytics - NERA Data Repository\Processed Data\NERA RapidMiner Repository\Evo_4_CE & Tech\Data\All Course Enrolments.rmhdf5table')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2481842 entries, 0 to 2481841
# Data columns (total 9 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Course Code       category
#  1   PIN               category
#  2   CourseTitle       category
#  3   Start Date        datetime64[ns]
#  4   Duration          float64
#  5   Enrolment Status  category
#  6   Asset Type        category
#  7   Completed Date    datetime64[ns]
#  8   Course Date       datetime64[ns]
# dtypes: category(5), datetime64[ns](3), float64(1)
# memory usage: 104.5 MB

# %%
filtered_df = df[df["Course Code"] == "VD0C03206"]
#filtered_df = filtered_df[filtered_df["PIN"].isin(["876994", "212261", "1175224"])]
sorted_df = filtered_df.sort_values(by="PIN")

# %%
filtered_df
# Out:
# Empty DataFrame
# Columns: [Course Code, PIN, CourseTitle, Start Date, Duration, Enrolment Status, Asset Type, Completed Date, Course Date]
# Index: []

# %%
filtered_df_1 = df[df["PIN"] == "212261"]
filtered_df_1
# Out:
#         Course Code     PIN  \
# 62173     CD1N03107  212261
# 283614    CDA901075  212261
# 317826    CDAN00134  212261
# 419736    ED1N00854  212261
# 451227    ED1N01074  212261
# 698873    ED2X00002  212261
# 798444    ED3103236  212261
# 958526    EDA101034  212261
# 1086179   EDA900974  212261
# 1141109   EDA901335  212261
# 1504686   EDMN00150  212261
# 1571363   ELA102631  212261
# 1638378     ELDU242  212261
# 1683957     ELDU243  212261
# 1977490   VD1N01732  212261
# 1999474   VD1N01733  212261
# 2018745   VD1N01734  212261
#
#                                                CourseTitle  \
# 62173                                              Welcome
# 283614                 Jaguar Land Rover Product Knowledge
# 317826                        Welcome to Jaguar Land Rover
# 419736                                  Introduction to SV
# 451227                   Introduction to Jaguar Land Rover
# 698873                                               TOPIx
# 798444                               Introduction to TOPIx
# 958526                 Electric Vehicles: Safety Awareness
# 1086179                                 InControl Overview
# 1141109                                  Pivi Pro Overview
# 1504686                               Retailer Empowerment
# 1571363  New Range Rover 22MY Product Knowledge (Techni...
# 1638378                                Welcome to Warranty
# 1683957                               The Warranty Process
# 1977490          Welcome to Jaguar Land Rover VCT (Part 1)
