# %% [markdown]
# ### SALAZAR ISrael ( Chile )
#
# * PIN -
# * 934567 - Technician L2
# * 720751 - Technician L3
# * 519667 - Technician L4
#
# * ADDRESS ID - **AD_464057

# %%
import os
import numpy as np
import pandas as pd
import rapidminer

rm = rapidminer.Studio("C:\Program Files\RapidMiner\RapidMiner Studio")

# %%
df = rapidminer.Project().read(r'C:\Users\ajain46\OneDrive\JAGUAR LAND ROVER\Network Excellence Reporting & Analytics - NERA Data Repository\Processed Data\NERA RapidMiner Repository\Evo_2_Users\Data\16_ExcellenceUsersActiveAsNewOrgWithFimsFields.rmhdf5table')
# Out:
# c:\Users\ajain46\Anaconda3\envs\NERA\lib\site-packages\rapidminer\core\project.py:121: H5pyDeprecationWarning: Using astype() as a context manager is deprecated. Slice the returned object instead, like: ds.astype(np.int32)[:10]
#   with x.astype('int64'):

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3224754 entries, 0 to 3224753
# Data columns (total 52 columns):
#  #   Column                                      Dtype
# ---  ------                                      -----
#  0   Brand                                       category
#  1   Business Region                             category
#  2   Market                                      category
#  3   Sub Market                                  category
#  4   Country                                     category
#  5   CustomerServiceMapping                      category
#  6   AddressIDExcellence                         category
#  7   CI Code                                     category
#  8   Retailer Name                               category
#  9   BusUnitType                                 category
#  10  BusUnitSubType                              category
#  11  Town                                        category
# ...

# %%
df[["Brand","Excellence Level","PIN","JobRoleActiveInactive","AddressIDExcellence"]].query('PIN==("519667","720751", "934567") and JobRoleActiveInactive == "Active" and AddressIDExcellence == "AD_464057" ').sort_values(by= "PIN")
# Out:
#              Brand Excellence Level     PIN JobRoleActiveInactive  \
# 178984  Land Rover          Level 4  519667                Active
# 178985  Land Rover          Level 4  519667                Active
# 179034      Jaguar          Level 4  519667                Active
# 179035      Jaguar          Level 4  519667                Active
# 178992  Land Rover          Level 3  934567                Active
# 178993  Land Rover          Level 3  934567                Active
# 179042      Jaguar          Level 3  934567                Active
# 179043      Jaguar          Level 3  934567                Active
# 178994  Land Rover          Level 3  720751                Active
# 178995  Land Rover          Level 3  720751                Active
# 179044      Jaguar          Level 3  720751                Active
# 179045      Jaguar          Level 3  720751                Active
#
#        AddressIDExcellence
# 178984           AD_464057
# 178985           AD_464057
# ...

# %% [markdown]
# ### EXCELLENCE ORG - 13

# %%
df_1 = rapidminer.Project().read(r'C:\Users\ajain46\OneDrive\JAGUAR LAND ROVER\Network Excellence Reporting & Analytics - NERA Data Repository\Processed Data\NERA RapidMiner Repository\Evo_2_Users\Data\13_ExcellenceUsersAsSource.rmhdf5table')

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1396671 entries, 0 to 1396670
# Data columns (total 32 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Brand                      1396671 non-null  category
#  1   Level_1                    1396671 non-null  category
#  2   Level_2                    1396671 non-null  category
#  3   Level_3                    1396671 non-null  category
#  4   Level_4                    1396671 non-null  category
#  5   Level_5                    1396671 non-null  category
#  6   AddressID                  1169044 non-null  category
#  7   CICode                     1396550 non-null  category
#  8   BusinessUnit               1396409 non-null  category
#  9   BusUnitType                1396550 non-null  category
#  10  BusUnitSubType             1396550 non-null  category
#  11  BusUnitStatus              1396550 non-null  category
# ...

# %%
df_1[["Brand","ExcellenceLevel","TargetLevelName","PIN","JobRoleActiveInactive","AddressID"]].query('PIN==("519667","720751", "934567") and JobRoleActiveInactive == "Active" and AddressID == "AD_464057" ').sort_values(by= "PIN")
# Out:
#               Brand ExcellenceLevel TargetLevelName     PIN  \
# 1348022      Jaguar             NaN             NaN  519667
# 1348233  Land Rover             NaN             NaN  519667
# 1348065      Jaguar             NaN             NaN  934567
# 1348254  Land Rover             NaN             NaN  934567
# 1348066      Jaguar             NaN             NaN  720751
# 1348255  Land Rover             NaN             NaN  720751
#
#         JobRoleActiveInactive  AddressID
# 1348022                Active  AD_464057
# 1348233                Active  AD_464057
# 1348065                Active  AD_464057
# 1348254                Active  AD_464057
# 1348066                Active  AD_464057
# 1348255                Active  AD_464057

# %% [markdown]
# ### EXCELLENCE ORG - 15

# %%
df_2 = rapidminer.Project().read(r'C:\Users\ajain46\OneDrive\JAGUAR LAND ROVER\Network Excellence Reporting & Analytics - NERA Data Repository\Processed Data\NERA RapidMiner Repository\Evo_2_Users\Data\15_ExcellenceUsersAllAsNewOrg.rmhdf5table')

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1396671 entries, 0 to 1396670
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   Brand                        1396671 non-null  category
#  1   Business Region              1396671 non-null  category
#  2   Market                       1396671 non-null  category
#  3   Sub Market                   1396671 non-null  category
#  4   Country                      1396671 non-null  category
#  5   CustomerServiceMapping       1385270 non-null  category
#  6   AddressIDExcellence          1169044 non-null  category
#  7   CI Code                      1396550 non-null  category
#  8   Retailer Name                1396409 non-null  category
#  9   BusUnitType                  1396550 non-null  category
#  10  BusUnitSubType               1396550 non-null  category
#  11  Retailer Status              1396550 non-null  category
# ...

# %%
df_2[["Brand","Excellence Level","Target Level","PIN","JobRoleActiveInactive","AddressIDExcellence"]].query('PIN==("519667","720751", "934567") and JobRoleActiveInactive == "Active" and AddressIDExcellence == "AD_464057" ').sort_values(by= "PIN")
# Out:
#               Brand Excellence Level Target Level     PIN  \
# 1040343      Jaguar          Level 0      Level 2  519667
# 1040554  Land Rover          Level 0      Level 2  519667
# 1040386      Jaguar          Level 0      Level 2  934567
# 1040575  Land Rover          Level 0      Level 2  934567
# 1040387      Jaguar          Level 0      Level 2  720751
# 1040576  Land Rover          Level 0      Level 2  720751
#
#         JobRoleActiveInactive AddressIDExcellence
# 1040343                Active           AD_464057
# 1040554                Active           AD_464057
# 1040386                Active           AD_464057
# 1040575                Active           AD_464057
# 1040387                Active           AD_464057
# 1040576                Active           AD_464057

# %% [markdown]
# ### 13 EXCELLENCE USERS AS SOURCE

# %%
df_3 = rapidminer.Project().read(r'C:\Users\ajain46\OneDrive\JAGUAR LAND ROVER\Network Excellence Reporting & Analytics - NERA Data Repository\Processed Data\NERA RapidMiner Repository\Evo_2_Users\Data\13_ExcellenceUsersAsSource')

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1396671 entries, 0 to 1396670
# Data columns (total 32 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Brand                      1396671 non-null  category
#  1   Level_1                    1396671 non-null  category
#  2   Level_2                    1396671 non-null  category
#  3   Level_3                    1396671 non-null  category
#  4   Level_4                    1396671 non-null  category
#  5   Level_5                    1396671 non-null  category
#  6   AddressID                  1169044 non-null  category
#  7   CICode                     1396550 non-null  category
#  8   BusinessUnit               1396409 non-null  category
#  9   BusUnitType                1396550 non-null  category
#  10  BusUnitSubType             1396550 non-null  category
#  11  BusUnitStatus              1396550 non-null  category
# ...

# %%
df_3[["Brand","ExcellenceLevel","TargetLevelName","PIN","JobRoleActiveInactive","AddressID"]].query('PIN==("519667","720751", "934567") and JobRoleActiveInactive == "Active" and AddressID == "AD_464057" ').sort_values(by= "PIN")
# Out:
#               Brand ExcellenceLevel TargetLevelName     PIN  \
# 1348022      Jaguar             NaN             NaN  519667
# 1348233  Land Rover             NaN             NaN  519667
# 1348065      Jaguar             NaN             NaN  934567
# 1348254  Land Rover             NaN             NaN  934567
# 1348066      Jaguar             NaN             NaN  720751
# 1348255  Land Rover             NaN             NaN  720751
#
#         JobRoleActiveInactive  AddressID
# 1348022                Active  AD_464057
# 1348233                Active  AD_464057
# 1348065                Active  AD_464057
# 1348254                Active  AD_464057
# 1348066                Active  AD_464057
# 1348255                Active  AD_464057

# %% [markdown]
# ### CHECKING INDIVISUAL EXCEL FILES TO SEE IF TECHNICIANS' LEVELS ARE CORRECTLY INDICATED
#
#
# ##### CERTHPATH

# %% [markdown]
# ####

# %%
ef=pd.read_csv(r'C:\Users\ajain46\OneDrive\JAGUAR LAND ROVER\Network Excellence Reporting & Analytics - NERA Data Repository\Raw Extracts\EvoReportingDB\CertPath.csv')  # Read the first sheet
# Out:
# c:\Users\ajain46\Anaconda3\envs\NERA\lib\site-packages\IPython\core\interactiveshell.py:3427: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
ef.head()
# Out:
#           CertPath    CurrentLevelName     TargetLevelName ExpirationDate  \
# 0       Technician                 NaN             Level 4            NaN
# 1       Technician                 NaN             Level 4            NaN
# 2       Technician                 NaN             Level 4            NaN
# 3       Technician                 NaN             Level 4            NaN
# 4  Sales Executive  Professional Level  Professional Level            NaN
#
#    IsTechnical  IsFastTrack                    LearnerJourneyUUID  \
# 0            1            0  6d70c17a-67e3-47e9-8a8f-66f0e3004ec4
# 1            1            0  6d70c17a-67e3-47e9-8a8f-66f0e3004ec4
# 2            1            0  6d70c17a-67e3-47e9-8a8f-66f0e3004ec4
# 3            1            0  6d70c17a-67e3-47e9-8a8f-66f0e3004ec4
# 4            0            0  9ad359d8-9c70-4e00-8cf9-38b44b0484e8
#
#                   EmploymentJobRoleUUID                              UserUUID  \
# ...

# %%
ef[["CertPath","TargetLevelName","PIN","CurrentStudyLevel","CompletionDate"]].query('PIN==["519667","720751","934567"]')
# Out:
#           CertPath TargetLevelName     PIN CurrentStudyLevel CompletionDate
# 461904  Technician         Level 3  934567           Level 3            NaN
# 461905  Technician         Level 3  934567           Level 3            NaN
# 461906  Technician         Level 3  934567           Level 3            NaN
# 461907  Technician         Level 3  934567           Level 3            NaN
# 461908  Technician         Level 3  934567           Level 3            NaN
# 461909  Technician         Level 3  934567           Level 3            NaN
# 461910  Technician         Level 3  934567           Level 3            NaN
# 461911  Technician         Level 3  934567           Level 3            NaN
